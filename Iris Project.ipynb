# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Iris.csv")
data=pd.DataFrame(df)
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#feature Analysis 
data.shape
# Out:
# (150, 6)

# %%
data.size
# Out:
# 900

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
#deleting the id column 
data.drop('Id', axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#to find indivisual species 
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#visual analysis 
import matplotlib.pyplot as plt
import seaborn as sns
fig =data[data.Species=='Iris-setosa'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='blue', label='Setosa',  figsize= (10,6))
data[data.Species=='Iris-versicolor'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='green', label='Iris-versicolor',  ax=fig)
data[data.Species=='Iris-virginica'].plot(kind='scatter',x='SepalLengthCm',y='SepalWidthCm',color='red', label='Iris-virginica',  ax=fig)
plt.show()

# %%
#finding comparison based on features . 
sns.stripplot(y='SepalLengthCm',x='Species',data=data)
plt.show()

# %%
sns.stripplot(y='SepalWidthCm',x='Species',data=data)
plt.show()

# %%
sns.stripplot(y='PetalWidthCm',x='Species',data=data)
plt.show()

# %%
sns.stripplot(y='PetalLengthCm',x='Species',data=data[data.Species=='Iris-setosa'])
plt.show()

# %%
data.hist(bins=10,figsize=(12,6))
plt.show()

# %%
sns.pairplot(data=data,hue='Species',height=3)
plt.show()

# %%
#Statiscal analysis
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
#finding mean and median for dataset .
data.groupby('Species').agg(['mean','median'])
# Out:
#                 SepalLengthCm        SepalWidthCm        PetalLengthCm         \
#                          mean median         mean median          mean median
# Species
# Iris-setosa             5.006    5.0        3.418    3.4         1.464   1.50
# Iris-versicolor         5.936    5.9        2.770    2.8         4.260   4.35
# Iris-virginica          6.588    6.5        2.974    3.0         5.552   5.55
#
#                 PetalWidthCm
#                         mean median
# Species
# Iris-setosa            0.244    0.2
# Iris-versicolor        1.326    1.3
# Iris-virginica         2.026    2.0

# %%
#choose all species whose sepal length >6
data.loc[data['SepalLengthCm']>6,['Species']].value_counts()
# Out:
# Species
# Iris-virginica     41
# Iris-versicolor    20
# dtype: int64

# %%
#machine learning models
#linear regression model
#features selection 
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict([[3.2,3.0,1.3,2.8]])
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
ypredict=model.predict(xtest)

# %%
#evaluation of a model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
print("the accuracy score",accuracy_score(ypredict,ytest))
# Out:
# the accuracy score 0.9

# %%
print(classification_report(ypredict,ytest))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.88      0.78      0.82         9
#  Iris-virginica       0.83      0.91      0.87        11
#
#        accuracy                           0.90        30
#       macro avg       0.90      0.90      0.90        30
#    weighted avg       0.90      0.90      0.90        30

# %%
#support vector 
from sklearn.svm import SVC
model=SVC()
model.fit(xtrain,ytrain)
ypredict=model.predict(xtest)

# %%
print(classification_report(ypredict,ytest))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      0.80      0.89        10
#  Iris-virginica       0.83      1.00      0.91        10
#
#        accuracy                           0.93        30
#       macro avg       0.94      0.93      0.93        30
#    weighted avg       0.94      0.93      0.93        30

# %%
#decision tree model
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(xtrain,ytrain)
ypredict=model.predict(xtest)

# %%
print(classification_report(ypredict,ytest))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.88      0.78      0.82         9
#  Iris-virginica       0.83      0.91      0.87        11
#
#        accuracy                           0.90        30
#       macro avg       0.90      0.90      0.90        30
#    weighted avg       0.90      0.90      0.90        30

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=8)
model.fit(xtrain, ytrain)

ypred = model.predict(xtest)

# %%
print(classification_report(ypredict,ytest))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       0.88      0.78      0.82         9
#  Iris-virginica       0.83      0.91      0.87        11
#
#        accuracy                           0.90        30
#       macro avg       0.90      0.90      0.90        30
#    weighted avg       0.90      0.90      0.90        30
